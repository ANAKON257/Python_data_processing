# %% [markdown]
# # Data Append Exercise:
# The datacollected is given in two files namely Preprocessing_Data_I and Preprocessing_Data_II. Can you append the second file with the first one?

# %%
#import the package
import pandas as mypd

# %%
#import the data1
mydata1=mypd.read_excel(r'D:\Python_ISI\data\Preprocessing_Data_I.xlsx')

# %%
mydata1
# Out:
#     SL No  Reviewer_Skill  Review_Type  Domain_Knowledge  Review_Time  \
# 0       1               4            1                 4         30.0
# 1       2               5            2                 5         20.0
# 2       3               4            1                 4         20.0
# 3       4               4            1                 4         30.0
# 4       5               5            2                 5          NaN
# 5       6               3            1                 3         30.0
# 6       7               4            2                 4         30.0
# 7       8               4            1                 4         20.0
# 8       9               3            1                 3         30.0
# 9      10               5            2                 5         20.0
# 10     11               3            1                 3         30.0
# 11     12               4            1                 4         30.0
# ...

# %%
#import the data2
mydata2=mypd.read_csv(r'D:\Python_ISI\data\Preprocessing_Data_II.csv')

# %%
mydata2
# Out:
#     SL No  Reviewer_Skill  Review_Type  Domain_Knowledge  Review_Time  \
# 0      21               5            2                 5         20.0
# 1      22               3            1                 3         20.0
# 2      23               4            1                 4         20.0
# 3      24               4            1                 4         20.0
# 4      25               3            1                 3          NaN
# 5      26               4            2                 4         30.0
# 6      27               3            1                 3         20.0
# 7      28               3            1                 3         20.0
# 8      29               4            2                 4         30.0
# 9      30               5            2                 5         20.0
# 10     31               4            2                 4         30.0
# 11     32               4            2                 4         30.0
# ...

# %%
#Append the files
mydata=mydata1.append(mydata2,ignore_index=True)
# Out:
# C:\Users\Anannya\AppData\Local\Temp\ipykernel_11120\426689538.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mydata=mydata1.append(mydata2,ignore_index=True)

# %%
mydata
# Out:
#     SL No  Reviewer_Skill  Review_Type  Domain_Knowledge  Review_Time  \
# 0       1               4            1                 4         30.0
# 1       2               5            2                 5         20.0
# 2       3               4            1                 4         20.0
# 3       4               4            1                 4         30.0
# 4       5               5            2                 5          NaN
# 5       6               3            1                 3         30.0
# 6       7               4            2                 4         30.0
# 7       8               4            1                 4         20.0
# 8       9               3            1                 3         30.0
# 9      10               5            2                 5         20.0
# 10     11               3            1                 3         30.0
# 11     12               4            1                 4         30.0
# ...

# %%
mydata.to_excel(r'D:\Python_ISI\Modified_data.xlsx',index=False)
